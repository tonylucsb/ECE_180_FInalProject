# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import mean_squared_error
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
import nltk
import random

torch.manual_seed(42)
np.random.seed(42)
random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
    torch.cuda.manual_seed_all(42)

nltk.download('punkt')

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\shuxu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
train_df = pd.read_csv("train.csv")
val_df = pd.read_csv("val.csv")
test_df = pd.read_csv("test.csv")

# %%
all_sentences = train_df['query'].tolist() + val_df['query'].tolist() + test_df['query'].tolist()
tokenized = [word_tokenize(sent.lower()) for sent in all_sentences]

w2v_model = Word2Vec(sentences=tokenized, vector_size=100, window=5, min_count=1, workers=4)

# %%
vocab = {"<PAD>": 0, "<UNK>": 1}
for sent in tokenized:
    for word in sent:
        if word not in vocab:
            vocab[word] = len(vocab)

embedding_matrix = np.zeros((len(vocab), 100))
for word, idx in vocab.items():
    if word in w2v_model.wv:
        embedding_matrix[idx] = w2v_model.wv[word]
    else:
        embedding_matrix[idx] = np.random.normal(scale=0.6, size=(100,))

# %%
class TextDataset(Dataset):
    def __init__(self, queries, labels, vocab, max_len=20):
        self.data = []
        for q, label in zip(queries, labels):
            tokens = word_tokenize(q.lower())
            indexed = [vocab.get(word, vocab["<UNK>"]) for word in tokens][:max_len]
            if len(indexed) < max_len:
                indexed += [vocab["<PAD>"]] * (max_len - len(indexed))
            self.data.append((torch.tensor(indexed), torch.tensor(label, dtype=torch.float)))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx]

# %%
import torch.nn as nn
import torch

class LSTMRegressor(nn.Module):
    def __init__(self, embedding_matrix, hidden_dim=64, num_layers=2, dropout=0.2, bidirectional=False):
        super(LSTMRegressor, self).__init__()
        vocab_size, embed_dim = embedding_matrix.shape

        self.embedding = nn.Embedding(vocab_size, embed_dim)
        self.embedding.weight.data.copy_(torch.tensor(embedding_matrix))
        self.embedding.weight.requires_grad = True  # Enable fine-tuning

        self.lstm = nn.LSTM(
            input_size=embed_dim,
            hidden_size=hidden_dim,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout if num_layers > 1 else 0.0,
            bidirectional=bidirectional
        )

        lstm_output_dim = hidden_dim * (2 if bidirectional else 1)
        self.fc = nn.Linear(lstm_output_dim, 1)

    def forward(self, x):
        x = self.embedding(x)
        _, (hn, _) = self.lstm(x)
        out = hn[-1]
        return self.fc(out).squeeze(1)

# %%
class RMSELoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.mse = nn.MSELoss()

    def forward(self, yhat, y):
        return torch.sqrt(self.mse(yhat, y))

# %%
batch_size = 32
epochs = 100

train_dataset = TextDataset(train_df['query'], train_df['carb'], vocab)
val_dataset = TextDataset(val_df['query'], val_df['carb'], vocab)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)

model = LSTMRegressor(embedding_matrix, num_layers = 5).to(device)
criterion = RMSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)

for epoch in range(epochs):
    model.train()
    total_loss = 0
    for x_batch, y_batch in train_loader:
        x_batch, y_batch = x_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        preds = model(x_batch)
        loss = criterion(preds, y_batch)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    print(f"Epoch {epoch+1}, Train RMSE: {total_loss / len(train_loader):.4f}")

    # Validation RMSE
    model.eval()
    val_preds, val_targets = [], []
    with torch.no_grad():
        for x_val, y_val in val_loader:
            x_val, y_val = x_val.to(device), y_val.to(device)
            preds = model(x_val)
            val_preds.append(preds.cpu())
            val_targets.append(y_val.cpu())

    val_preds = torch.cat(val_preds)
    val_targets = torch.cat(val_targets)
    val_rmse = torch.sqrt(nn.MSELoss()(val_preds, val_targets))
    print(f"           Val RMSE: {val_rmse.item():.4f}")
# Out:
# Epoch 1, Train RMSE: 35.0429
#            Val RMSE: 39.7085
# Epoch 2, Train RMSE: 34.3569
#            Val RMSE: 39.5235
# Epoch 3, Train RMSE: 34.5364
#            Val RMSE: 39.5185
# Epoch 4, Train RMSE: 34.3208
#            Val RMSE: 39.4944
# Epoch 5, Train RMSE: 34.4210
#            Val RMSE: 39.4568
# Epoch 6, Train RMSE: 34.4950
#            Val RMSE: 39.4665
# Epoch 7, Train RMSE: 34.6271
#            Val RMSE: 39.4815
# Epoch 8, Train RMSE: 34.7914
#            Val RMSE: 38.8438
# Epoch 9, Train RMSE: 32.3220
#            Val RMSE: 37.9220
# Epoch 10, Train RMSE: 32.2038
#            Val RMSE: 37.6684
# Epoch 11, Train RMSE: 31.2227
#            Val RMSE: 36.1114
# Epoch 12, Train RMSE: 30.1810
#            Val RMSE: 35.9601
# Epoch 13, Train RMSE: 30.1940
#            Val RMSE: 36.1214
# Epoch 14, Train RMSE: 29.5998
#            Val RMSE: 36.0142
# Epoch 15, Train RMSE: 30.2201
#            Val RMSE: 36.0208
# Epoch 16, Train RMSE: 32.0304
#            Val RMSE: 37.5401
# Epoch 17, Train RMSE: 32.3447
#            Val RMSE: 36.3528
# Epoch 18, Train RMSE: 29.9060
#            Val RMSE: 35.4112
# Epoch 19, Train RMSE: 28.7997
#            Val RMSE: 34.7021
# Epoch 20, Train RMSE: 27.7053
#            Val RMSE: 33.6467
# Epoch 21, Train RMSE: 27.0573
#            Val RMSE: 33.2464
# Epoch 22, Train RMSE: 26.6623
#            Val RMSE: 33.0107
# Epoch 23, Train RMSE: 25.4714
#            Val RMSE: 32.3004
# Epoch 24, Train RMSE: 24.8995
#            Val RMSE: 31.6546
# Epoch 25, Train RMSE: 24.4058
#            Val RMSE: 31.2870
# Epoch 26, Train RMSE: 24.0304
#            Val RMSE: 31.2374
# Epoch 27, Train RMSE: 24.0873
#            Val RMSE: 30.8773
# Epoch 28, Train RMSE: 23.0465
#            Val RMSE: 30.5844
# Epoch 29, Train RMSE: 22.5235
#            Val RMSE: 29.9458
# Epoch 30, Train RMSE: 22.1835
#            Val RMSE: 29.7246
# Epoch 31, Train RMSE: 21.5151
#            Val RMSE: 29.1650
# Epoch 32, Train RMSE: 21.2469
#            Val RMSE: 29.2408
# Epoch 33, Train RMSE: 20.9771
#            Val RMSE: 28.5957
# Epoch 34, Train RMSE: 20.8045
#            Val RMSE: 28.9498
# Epoch 35, Train RMSE: 21.0303
#            Val RMSE: 28.9882
# Epoch 36, Train RMSE: 20.4248
#            Val RMSE: 28.7948
# Epoch 37, Train RMSE: 19.3893
#            Val RMSE: 28.3126
# Epoch 38, Train RMSE: 19.0363
#            Val RMSE: 27.5675
# Epoch 39, Train RMSE: 19.0254
#            Val RMSE: 27.1386
# Epoch 40, Train RMSE: 18.5482
#            Val RMSE: 26.8404
# Epoch 41, Train RMSE: 18.1165
#            Val RMSE: 26.6574
# Epoch 42, Train RMSE: 17.6409
#            Val RMSE: 26.6646
# Epoch 43, Train RMSE: 17.4564
#            Val RMSE: 26.7692
# Epoch 44, Train RMSE: 17.1633
#            Val RMSE: 26.5096
# Epoch 45, Train RMSE: 17.1498
#            Val RMSE: 26.3459
# Epoch 46, Train RMSE: 16.8995
#            Val RMSE: 27.4870
# Epoch 47, Train RMSE: 16.4646
#            Val RMSE: 26.1856
# Epoch 48, Train RMSE: 16.5445
#            Val RMSE: 27.0262
# Epoch 49, Train RMSE: 15.9338
#            Val RMSE: 25.6786
# Epoch 50, Train RMSE: 16.1694
#            Val RMSE: 25.5634
# Epoch 51, Train RMSE: 15.6168
#            Val RMSE: 25.5837
# Epoch 52, Train RMSE: 15.4473
#            Val RMSE: 25.5703
# Epoch 53, Train RMSE: 15.4751
#            Val RMSE: 25.5772
# Epoch 54, Train RMSE: 14.8563
#            Val RMSE: 25.9164
# Epoch 55, Train RMSE: 15.1016
#            Val RMSE: 25.9080
# Epoch 56, Train RMSE: 14.3589
#            Val RMSE: 25.7536
# Epoch 57, Train RMSE: 13.8149
#            Val RMSE: 25.8741
# Epoch 58, Train RMSE: 14.3566
#            Val RMSE: 25.4579
# Epoch 59, Train RMSE: 14.4854
#            Val RMSE: 25.4763
# Epoch 60, Train RMSE: 13.7109
#            Val RMSE: 25.2466
# Epoch 61, Train RMSE: 13.6425
#            Val RMSE: 25.1459
# Epoch 62, Train RMSE: 14.6294
#            Val RMSE: 25.9074
# Epoch 63, Train RMSE: 14.0997
#            Val RMSE: 26.3091
# Epoch 64, Train RMSE: 13.6737
#            Val RMSE: 23.8584
# Epoch 65, Train RMSE: 13.4557
#            Val RMSE: 28.2202
# Epoch 66, Train RMSE: 14.5726
#            Val RMSE: 24.7443
# Epoch 67, Train RMSE: 13.2369
#            Val RMSE: 25.0658
# Epoch 68, Train RMSE: 13.0564
#            Val RMSE: 25.1846
# Epoch 69, Train RMSE: 12.9982
#            Val RMSE: 25.1025
# Epoch 70, Train RMSE: 12.4921
#            Val RMSE: 25.2302
# Epoch 71, Train RMSE: 13.3457
#            Val RMSE: 27.1895
# Epoch 72, Train RMSE: 14.5040
#            Val RMSE: 23.8671
# Epoch 73, Train RMSE: 12.8482
#            Val RMSE: 24.3215
# Epoch 74, Train RMSE: 12.3571
#            Val RMSE: 23.0322
# Epoch 75, Train RMSE: 12.1297
#            Val RMSE: 23.2737
# Epoch 76, Train RMSE: 11.9728
#            Val RMSE: 24.1741
# Epoch 77, Train RMSE: 11.5866
#            Val RMSE: 23.2883
# Epoch 78, Train RMSE: 11.3631
#            Val RMSE: 23.3263
# Epoch 79, Train RMSE: 11.4167
#            Val RMSE: 24.5332
# Epoch 80, Train RMSE: 11.4989
#            Val RMSE: 23.9916
# Epoch 81, Train RMSE: 11.1535
#            Val RMSE: 24.6269
# Epoch 82, Train RMSE: 11.2542
#            Val RMSE: 25.4280
# Epoch 83, Train RMSE: 11.6435
#            Val RMSE: 22.6758
# Epoch 84, Train RMSE: 11.0471
#            Val RMSE: 22.7973
# Epoch 85, Train RMSE: 11.1428
#            Val RMSE: 22.0383
# Epoch 86, Train RMSE: 10.4497
#            Val RMSE: 22.6580
# Epoch 87, Train RMSE: 12.3859
#            Val RMSE: 23.5997
# Epoch 88, Train RMSE: 11.9361
#            Val RMSE: 23.9718
# Epoch 89, Train RMSE: 11.5532
#            Val RMSE: 24.8631
# Epoch 90, Train RMSE: 11.6492
#            Val RMSE: 24.7132
# Epoch 91, Train RMSE: 10.6802
#            Val RMSE: 22.9436
# Epoch 92, Train RMSE: 10.7880
#            Val RMSE: 23.2991
# Epoch 93, Train RMSE: 10.4396
#            Val RMSE: 23.1486
# Epoch 94, Train RMSE: 10.2299
#            Val RMSE: 23.5840
# Epoch 95, Train RMSE: 10.1711
#            Val RMSE: 23.2795
# Epoch 96, Train RMSE: 10.1270
#            Val RMSE: 22.2239
# Epoch 97, Train RMSE: 9.9290
#            Val RMSE: 22.8361
# Epoch 98, Train RMSE: 10.0537
#            Val RMSE: 21.6561
# Epoch 99, Train RMSE: 9.5628
#            Val RMSE: 21.9541
# Epoch 100, Train RMSE: 9.8071
#            Val RMSE: 23.5684
